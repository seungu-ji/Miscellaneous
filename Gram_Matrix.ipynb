# %% [markdown]
# <a href="https://colab.research.google.com/github/viriditass/Miscellaneous/blob/main/Gram_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Gram Matrix**

# %% [markdown]
# Style Transfer에 나오는 개념인 Gram Matrix에 대해 알아보겠다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 만일 이미지가 위와 같이 너비가 3이고 높이가 1이라고 가정을 하겠다. (pixel단위로 계산하며 왼쪽부터 픽셀을 x_0, x_1, x_2라고 정의)
#
# 그리고 z_0과 z_1이라는 2개의 필터로 저 이미지를 넣게 되면
#
# (이때 너비인 3이 M이 되며, 필터의 개수는 N이 된다.)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (만일 높이가 1보다 클 경우 높이가 1인 벡터형태로 맞춰주기 위해 위와 같이 높이를 1로 만들어준다.)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 아무튼 결과적으로 위와 같은 output을 얻게 된다. 그리고 이런 output을 F라고 정의를 하며, F_ik가 즉 한 pixel(= z_i(x_j))이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 이때 Gram Matrix는 위와 같은 식으로 정의가 된다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 그리고 이를 그림으로 나타내면 위와 같이 된다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 그리고 이를 위의 식과 같이 normalization하고

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# loss를 적용한 것이다.

# %% [markdown]
# 즉, 위의 내용을 이용해 생각해보자면 Gram Matrix를 활용하여 해당 style image의 분포를 content image에 적용시킨 것이 바로 style transfer 원리이다.
