# %% [markdown]
# <a href="https://colab.research.google.com/github/viriditass/Miscellaneous/blob/main/Intersection_over_Union.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Intersection over Union**

# %% [markdown]
# Intersection over Union, 일명 IoU는 object detection에서 쓰이는 도구다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# IOU의 정의는 위의 그림과 같다. (교집합 / 합집합)이다.

# %% [markdown]
# 두 box의 크기가 동일할 경우 두 box의 2/3는 겹쳐줘야 0.5의 값이 나오기 때문에
#
#
#
# 여러 곳에서 IoU의 threshold 값으로 0.5를 잡아서 사용하는 듯 하다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 모델의 성능을 높여보고자 IoU threshold 값을 올려서 모델링을 해도 되기는 하는데, 모델 성능이라는 게 feature extractor, classifier, regressor, IoU, NMS 등 여러가지가 복합적으로 얽혀있기 때문에 단순히 threshold 값을 올려준다해서 무조건 성능이 올라가지는 않는다.
